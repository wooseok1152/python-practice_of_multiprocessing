# %%
""" 

'액면가'값이 '\N'이 아닌 'KOSDAQ'상장 증권만 조회한 후, 해당 조회 결과에 '액면가 * 2'값이 저장된 'NEW_액면가'컬럼을 생성하기 

"""

# 주어진 연산을 '병렬처리'로 수행할 것
# 'Manager.Queue 객체'와, 'Process 객체'를 활용할 것
# 활용되는 process 개수 : CPU core 개수 // 2
# (EX. CPU core 개수 : 4 -> 'df_of_stock_master'을 '두 개'로 분할하고, '두 개'의 프로세스가 주어진 연산을 병렬로 실시)

# subprocess들의 pid를 출력하여, 주어진 연산을 병렬처리 했다는 사실을 나타낼 것
# pid 출력 : os.getpid()

# CPU core 개수 조회 : os.cpu_count()
# DataFrame을 n개로 분할 : np.array_split()

# 'sqldf'함수를 활용하여, 'NEW_액면가'컬럼을 생성할 것
# (pandas 문법 사용을 지양할 것)
# 'pandasql'패키지가 없다면, 해당 패키지를 설치할 것

import pandas as pd
from pandasql import sqldf

df_of_stock_master = pd.read_csv("./csv/SEC01H_20220501.csv")
print("* df_of_stock_master :", "\n")
display(df_of_stock_master)

print("* schema of df :")
display(df_of_stock_master.dtypes)
# Out:
# * df_of_stock_master :
#           기준일자          표준코드     단축코드            한글 종목명  한글 종목약명  \
# 0     20220501  KR7098120009  A098120      (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1     20220501  KR7131100000  A131100         (주)스카이이앤엠   스카이이앤엠
# 2     20220501  KR7009520008  A009520          (주)포스코엠텍    포스코엠텍
# 3     20220501  KR7095570008  A095570         AJ네트웍스보통주   AJ네트웍스
# 4     20220501  KR7006840003  A006840          AK홀딩스보통주    AK홀딩스
# ...        ...           ...      ...               ...      ...
# 2619  20220501  KR7000542001  A000547  흥국화재해상보험2우선주(신형)  흥국화재2우B
# 2620  20220501  KR7000540005  A000540       흥국화재해상보험보통주     흥국화재
# 2621  20220501  KR7003280005  A003280           흥아해운보통주     흥아해운
# 2622  20220501  KR7037440005  A037440        희림종합건축사사무소       희림
# 2623  20220501  KR7238490007  A238490                힘스       힘스
#
#                                영문 종목명       상장일    시장구분 증권구분          소속부  \
# 0     Micro Contact Solution Co.,Ltd.  20080923  KOSDAQ   주권        벤처기업부
# 1                   SKY E&M Co., Ltd.  20110614  KOSDAQ   주권  관리종목(소속부없음)
# 2               POSCO M-TECH CO.,LTD.  19971110  KOSDAQ   주권        우량기업부
# 3                AJ Networks Co.,Ltd.  20150821   KOSPI   주권           \N
# 4                   AK Holdings, Inc.  19990811   KOSPI   주권           \N
# ...                               ...       ...     ...  ...          ...
# 2619      HeungkukFire&MarineIns(2PB)  19990809   KOSPI   주권           \N
# 2620     HeungkukFire&MarineInsurance  19741205   KOSPI   주권           \N
# 2621                   HeungaShipping  19760629   KOSPI   주권           \N
# 2622     Heerim Architects & Planners  20000203  KOSDAQ   주권        중견기업부
# 2623                   HIMS CO., LTD.  20170720  KOSDAQ   주권        우량기업부
#
#        주식종류   액면가      상장주식수
# 0       보통주   500    8312766
# 1       보통주   500   12250629
# 2       보통주   500   41642703
# 3       보통주  1000   46822295
# 4       보통주  5000   13247561
# ...     ...   ...        ...
# 2619  신형우선주  5000     153600
# 2620    보통주  5000   64242645
# 2621    보통주   500  240424899
# 2622    보통주   500   13922475
# 2623    보통주   500   11312236
#
# [2624 rows x 13 columns]
# * schema of df :
# 기준일자        int64
# 표준코드       object
# 단축코드       object
# 한글 종목명     object
# 한글 종목약명    object
# 영문 종목명     object
# 상장일         int64
# 시장구분       object
# 증권구분       object
# 소속부        object
# 주식종류       object
# 액면가        object
# 상장주식수       int64
# dtype: object
